# %% [markdown]
# # Employee Attrition - Visualizing the Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
employee_data = pd.read_csv("data/prepared-employee_attrition.csv")

# %%
plt.figure(figsize=(13,9))
sns.heatmap(employee_data.corr(),vmax=0.8,linewidth=0.1,cmap='coolwarm')
plt.show()
# Out:
# /var/folders/lv/cdmppqs55q13tclc8s4bm67r0000gn/T/ipykernel_31318/1349563610.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(employee_data.corr(),vmax=0.8,linewidth=0.1,cmap='coolwarm')
